# %%
# https://www.youtube.com/watch?v=hFa6sYJnTfs&list=PLWzLQn_hxe6ZlC9-YMt3nN0Eo-ZpOJuXd&index=17
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Solamente para usuarios de Jupyter Themes
from jupyterthemes import jtplot
jtplot.reset()

# %%
from get_images import get_images

# %%
W = np.random.randn(100, 784)

# %%
W.ravel().shape
# Out:
# (78400,)

# %%
W.mean(), W.std()
# Out:
# (0.001271126111281772, 1.00256234104379)

# %%
plt.figure()
plt.hist(W.ravel(), bins=30, range=[-3, 3])
plt.show()

# %%
W2 = np.random.randn(100, 784) * 0.001
W2.mean(), W.std()
# Out:
# (-4.311858603478907e-06, 1.00256234104379)

# %%
plt.figure()
plt.hist(W2.ravel(), bins=30, range=[-0.003, 0.003])
plt.show()
